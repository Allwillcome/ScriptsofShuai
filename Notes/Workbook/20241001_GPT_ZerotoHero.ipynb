# %%
# !pip install micrograd

# %%
from micrograd.engine import Value

# %%
a = Value(-4.0)

# %%
a
# Out:
# Value(data=-4.0, grad=0)

# %%
b = Value(2.0)

# %%
c = a + b

# %%
c
# Out:
# Value(data=-2.0, grad=0)

# %%
d = a * b * b**3

# %%
d
# Out:
# Value(data=-64.0, grad=0)

# %%
c += c+1

# %%
c
# Out:
# Value(data=-3.0, grad=0)

# %%
d = d *2 + (b+a).relu()

# %%
d =
# Out:
# Value(data=-256.0, grad=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 -64 * 2 + (-2).relu()
#
# AttributeError: 'int' object has no attribute 'relu'
